# %% [markdown]
# <h3><strong>Doc Based QA System using Retrival Techniques</strong></h3>
# <ul><strong>Scope:</strong>
# <li>Given Doc extract jsonlines</li>
#
# </ul>
# <li>Expectation :<strong> Reduce hallucination</strong>

# %% [markdown]
# ### **INSTALL LIBRARIES**

# %%
# !pip install PdfReader
# !pip install langchain==0.1.4
# !pip install PyPDF2
# !pip install InstructorEmbedding
# !pip install sentence_transformers
# !pip install faiss
# !pip install faiss-gpu
# !pip install textract
#!pip install einops
# !pip install --upgrade --quiet  docx2txt
# !pip install unstructured
# !pip install "unstructured[doc]"
# !pip install langchain_community==0.0.14
# Out:
# Collecting PdfReader
#   Downloading pdfreader-0.1.12.tar.gz (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting bitarray>=1.1.0 (from PdfReader)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from PdfReader) (9.4.0)
# Collecting pycryptodome>=3.9.9 (from PdfReader)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 64.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from PdfReader) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->PdfReader) (1.16.0)
# Building wheels for collected packages: PdfReader
#   Building wheel for PdfReader (setup.py) ... done
#   Created wheel for PdfReader: filename=pdfreader-0.1.12-py3-none-any.whl size=134538 sha256=00b74ebb224aff250a85ffb09e8aaeda1e216f96de232006413071caa71e9e0e
#   Stored in directory: /root/.cache/pip/wheels/92/7d/f1/8b8a503d8b444a82e4c3c8b1230c02316c7579b90542de4495
# Successfully built PdfReader
# Installing collected packages: bitarray, pycryptodome, PdfReader
# Successfully installed PdfReader-0.1.12 bitarray-2.9.2 pycryptodome-3.20.0
# Collecting langchain==0.1.4
#   Downloading langchain-0.1.4-py3-none-any.whl (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (2.0.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain==0.1.4)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain==0.1.4)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.14 (from langchain==0.1.4)
#   Downloading langchain_community-0.0.17-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.8 MB/s eta 0:00:00
# Collecting langchain-core<0.2,>=0.1.16 (from langchain==0.1.4)
#   Downloading langchain_core-0.1.18-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.0/237.0 kB 30.8 MB/s eta 0:00:00
# Collecting langsmith<0.1,>=0.0.83 (from langchain==0.1.4)
#   Downloading langsmith-0.0.85-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (1.10.14)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.4) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.4) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.4) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.4) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.4) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.4) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.4)
#   Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.9 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.4)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain==0.1.4)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.16->langchain==0.1.4) (3.7.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.16->langchain==0.1.4) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.1.4) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.1.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.1.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.1.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.1.4) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.4) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain==0.1.4) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain==0.1.4) (1.2.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.4)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, jsonpointer, typing-inspect, langsmith, jsonpatch, langchain-core, dataclasses-json, langchain-community, langchain
# Successfully installed dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.4 langchain-community-0.0.17 langchain-core-0.1.18 langsmith-0.0.85 marshmallow-3.20.2 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting InstructorEmbedding
#   Downloading InstructorEmbedding-1.0.1-py2.py3-none-any.whl (19 kB)
# Installing collected packages: InstructorEmbedding
# Successfully installed InstructorEmbedding-1.0.1
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-2.3.1
# ERROR: Could not find a version that satisfies the requirement faiss (from versions: none)
# ERROR: No matching distribution found for faiss
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 8.9 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2
# Collecting textract
#   Downloading textract-1.6.5-py3-none-any.whl (23 kB)
# Collecting argcomplete~=1.10.0 (from textract)
#   Downloading argcomplete-1.10.3-py2.py3-none-any.whl (36 kB)
# Collecting beautifulsoup4~=4.8.0 (from textract)
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 1.9 MB/s eta 0:00:00
# Collecting chardet==3.* (from textract)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.4 MB/s eta 0:00:00
# Collecting docx2txt~=0.8 (from textract)
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting extract-msg<=0.29.* (from textract)
#   Downloading extract_msg-0.28.7-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.6 MB/s eta 0:00:00
# Collecting pdfminer.six==20191110 (from textract)
#   Downloading pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 28.7 MB/s eta 0:00:00
# Collecting python-pptx~=0.6.18 (from textract)
#   Downloading python_pptx-0.6.23-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 51.4 MB/s eta 0:00:00
# Collecting six~=1.12.0 (from textract)
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition~=3.8.1 (from textract)
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 33.8 MB/s eta 0:00:00
# Collecting xlrd~=1.2.0 (from textract)
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (3.20.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract) (2.5)
# Collecting imapclient==2.1.0 (from extract-msg<=0.29.*->textract)
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 10.3 MB/s eta 0:00:00
# Collecting olefile>=0.46 (from extract-msg<=0.29.*->textract)
#   Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (5.2)
# Collecting compressed-rtf>=1.0.6 (from extract-msg<=0.29.*->textract)
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ebcdic>=1.1.1 (from extract-msg<=0.29.*->textract)
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (4.9.4)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (9.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx~=0.6.18->textract)
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 20.6 MB/s eta 0:00:00
# Building wheels for collected packages: docx2txt, compressed-rtf
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=30216f4fd5b59fa1e3c73d8ea372135621266f95866a83c9e0b9c58ee5b2b117
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
#   Building wheel for compressed-rtf (setup.py) ... done
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6184 sha256=8d6f3926405d015a5d7339f465bf777d56dad6dfd98dda57c23ecef8c8b871ce
#   Stored in directory: /root/.cache/pip/wheels/15/3e/48/e7d833ecc516c36f8966d310b1a6386db091a718f1ff3bf85c
# Successfully built docx2txt compressed-rtf
# Installing collected packages: SpeechRecognition, ebcdic, docx2txt, compressed-rtf, chardet, argcomplete, XlsxWriter, xlrd, six, olefile, beautifulsoup4, python-pptx, pdfminer.six, imapclient, extract-msg, textract
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# pydrive2 1.6.3 requires six>=1.13.0, but you have six 1.12.0 which is incompatible.
# yfinance 0.2.36 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.8.2 which is incompatible.
# Successfully installed SpeechRecognition-3.8.1 XlsxWriter-3.1.9 argcomplete-1.10.3 beautifulsoup4-4.8.2 chardet-3.0.4 compressed-rtf-1.0.6 docx2txt-0.8 ebcdic-1.1.1 extract-msg-0.28.7 imapclient-2.1.0 olefile-0.47 pdfminer.six-20191110 python-pptx-0.6.23 six-1.12.0 textract-1.6.5 xlrd-1.2.0
# Collecting unstructured
#   Downloading unstructured-0.12.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.0.4)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.8.2)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 47.9 MB/s eta 0:00:00
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.6.4)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.1.2-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 38.4 MB/s eta 0:00:00
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 60.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.23.5)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 50.8 MB/s eta 0:00:00
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.5.0)
# Collecting unstructured-client>=0.15.1 (from unstructured)
#   Downloading unstructured_client-0.17.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.14.1)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (2023.11.17)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (3.3.2)
# Collecting dataclasses-json-speakeasy>=0.5.11 (from unstructured-client>=0.15.1->unstructured)
#   Downloading dataclasses_json_speakeasy-0.5.11-py3-none-any.whl (28 kB)
# Requirement already satisfied: idna>=3.4 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (3.6)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client>=0.15.1->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: marshmallow>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (3.20.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (2.8.2)
# Collecting six>=1.16.0 (from unstructured-client>=0.15.1->unstructured)
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-inspect>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (0.9.0)
# Collecting typing-extensions (from unstructured)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: urllib3>=1.26.18 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (2.0.7)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (4.66.1)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=74a2ea8315986b587e87542903ff6a17e5e212c591816b679c5126ee6cc8b422
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: filetype, typing-extensions, six, rapidfuzz, python-magic, python-iso639, jsonpath-python, emoji, backoff, langdetect, dataclasses-json-speakeasy, unstructured-client, unstructured
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: six
#     Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# textract 1.6.5 requires six~=1.12.0, but you have six 1.16.0 which is incompatible.
# yfinance 0.2.36 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.8.2 which is incompatible.
# Successfully installed backoff-2.2.1 dataclasses-json-speakeasy-0.5.11 emoji-2.10.1 filetype-1.2.0 jsonpath-python-1.0.6 langdetect-1.0.9 python-iso639-2024.1.2 python-magic-0.4.27 rapidfuzz-3.6.1 six-1.16.0 typing-extensions-4.9.0 unstructured-0.12.3 unstructured-client-0.17.0
# Requirement already satisfied: unstructured[doc] in /usr/local/lib/python3.10/dist-packages (0.12.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (3.0.4)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (0.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (4.8.2)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (2.10.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (0.6.4)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (2024.1.2)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (1.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (1.23.5)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (3.6.1)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (4.9.0)
# Requirement already satisfied: unstructured-client>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (0.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured[doc]) (1.14.1)
# Collecting python-docx (from unstructured[doc])
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (2023.11.17)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (3.3.2)
# Requirement already satisfied: dataclasses-json-speakeasy>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (0.5.11)
# Requirement already satisfied: idna>=3.4 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (3.6)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (3.20.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (2.8.2)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (1.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (0.9.0)
# Requirement already satisfied: urllib3>=1.26.18 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[doc]) (2.0.7)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured[doc]) (2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[doc]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[doc]) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[doc]) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[doc]) (4.66.1)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0
# Collecting langchain_community==0.0.14
#   Downloading langchain_community-0.0.14-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (2.0.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (0.6.4)
# Requirement already satisfied: langchain-core<0.2,>=0.1.14 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (0.1.18)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (0.0.85)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (1.23.5)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.0.14) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.14) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.14) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.14) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.14) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.14) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.14) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.14) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.14) (0.9.0)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (3.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (1.10.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.0.14) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.0.14) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.0.14) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.0.14) (2023.11.17)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.0.14) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.0.14) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (1.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1.14->langchain_community==0.0.14) (2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.14) (1.0.0)
# Installing collected packages: langchain_community
#   Attempting uninstall: langchain_community
#     Found existing installation: langchain-community 0.0.17
#     Uninstalling langchain-community-0.0.17:
#       Successfully uninstalled langchain-community-0.0.17
# Successfully installed langchain_community-0.0.14

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# #### **TRAVERSE DIRECTORY IN COLAB**

# %%
from google.colab import drive
drive.mount('./content/')

# !cd '/content/'
# Out:
# Mounted at ./content/

# %% [markdown]
# ### **IMPORT LIBRARIES**

# %%
from PyPDF2 import PdfReader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, HuggingFaceInstructEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFaceHub
import os
from langchain.prompts.prompt import PromptTemplate

# %%
# !apt install libreoffice
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common firebird3.0-common
#   firebird3.0-common-doc firebird3.0-server-core firebird3.0-utils fonts-crosextra-caladea
#   fonts-crosextra-carlito fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3
#   hunspell-en-us libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5 libcolamd2 libe-book-0.1-1
#   libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfbclient2 libfontenc1 libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgudev-1.0-0 libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0
#   libhyphen0 libib-util libjsp-api-java liblangtag-common liblangtag1 liblibreoffice-java libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0 libreoffice-base
#   libreoffice-base-core libreoffice-base-drivers libreoffice-calc libreoffice-common
#   libreoffice-core libreoffice-draw libreoffice-gnome libreoffice-gtk3 libreoffice-impress
#   libreoffice-java-common libreoffice-math libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh libreoffice-script-provider-js
#   libreoffice-script-provider-python libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb
#   libreoffice-sdbc-mysql libreoffice-sdbc-postgresql libreoffice-style-colibre
#   libreoffice-style-elementary libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librevenge-0.0-0 libservlet-api-java libservlet3.1-java libsuitesparseconfig5 libtext-iconv-perl
#   libtommath1 libuno-cppu3 libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoloader-java libvisio-0.1-1 libwebsocket-api-java libwpd-0.10-10
#   libwpg-0.3-3 libwps-0.4-4 libxkbfile1 libxmlsec1 libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2
#   lp-solve openjdk-11-jre poppler-data python3-uno uno-libs-private ure ure-java x11-utils
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist firebird3.0-server
#   firebird3.0-doc hunspell openoffice.org-hunspell | openoffice.org-core java-virtual-machine
#   libhsqldb1.8.0-java-gcj raptor2-utils rasqal-utils librdf-storage-postgresql librdf-storage-mysql
#   librdf-storage-sqlite librdf-storage-virtuoso redland-utils cups-bsd firefox | firefox-esr
#   | thunderbird ghostscript gpa hyphen-hyphenation-patterns imagemagick
#   | graphicsmagick-imagemagick-compat libreoffice-grammarcheck libreoffice-help libreoffice-l10n
#   libreoffice-librelogo myspell-dictionary mythes-thesaurus openclipart-libreoffice pstoedit
#   unixodbc gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-plugins-ugly
#   gstreamer1.0-plugins-bad gstreamer1.0-libav libsane1 libofficebean-java libjtds-java
#   libsqliteodbc | tdsodbc | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data bluez
#   default-mysql-server | virtual-mysql-server postgresql mediawiki poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum mesa-utils
# The following NEW packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common firebird3.0-common
#   firebird3.0-common-doc firebird3.0-server-core firebird3.0-utils fonts-crosextra-caladea
#   fonts-crosextra-carlito fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3
#   hunspell-en-us libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5 libcolamd2 libe-book-0.1-1
#   libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfbclient2 libfontenc1 libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgudev-1.0-0 libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0
#   libhyphen0 libib-util libjsp-api-java liblangtag-common liblangtag1 liblibreoffice-java libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0 libreoffice
#   libreoffice-base libreoffice-base-core libreoffice-base-drivers libreoffice-calc
#   libreoffice-common libreoffice-core libreoffice-draw libreoffice-gnome libreoffice-gtk3
#   libreoffice-impress libreoffice-java-common libreoffice-math libreoffice-nlpsolver
#   libreoffice-report-builder libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python libreoffice-sdbc-firebird
#   libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql libreoffice-sdbc-postgresql
#   libreoffice-style-colibre libreoffice-style-elementary libreoffice-style-yaru
#   libreoffice-wiki-publisher libreoffice-writer librevenge-0.0-0 libservlet-api-java
#   libservlet3.1-java libsuitesparseconfig5 libtext-iconv-perl libtommath1 libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3
#   libunoloader-java libvisio-0.1-1 libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4
#   libxkbfile1 libxmlsec1 libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2 lp-solve openjdk-11-jre
#   poppler-data python3-uno uno-libs-private ure ure-java x11-utils
# 0 upgraded, 128 newly installed, 0 to remove and 32 not upgraded.
# Need to get 227 MB of archives.
# After this operation, 855 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-opensymbol all 2:102.12+LibO7.3.7-0ubuntu0.22.04.4 [102 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-colibre all 1:7.3.7-0ubuntu0.22.04.4 [1,294 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-sal3 amd64 1:7.3.7-0ubuntu0.22.04.4 [196 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.4 [17.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppu3 amd64 1:7.3.7-0ubuntu0.22.04.4 [87.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 uno-libs-private amd64 1:7.3.7-0ubuntu0.22.04.4 [232 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag-common all 0.6.3-2ubuntu1 [193 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag1 amd64 0.6.3-2ubuntu1 [53.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.4 [343 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.4 [15.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure amd64 1:7.3.7-0ubuntu0.22.04.4 [1,312 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-common all 1:7.3.7-0ubuntu0.22.04.4 [23.4 MB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabsl20210324 amd64 0~20210324.2-2 [387 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [530 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [96.7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libeot0 amd64 0.01-5build2 [28.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-data all 3.4.5-1build2 [179 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1build2 [13.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.1 [136 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgmepp6 amd64 1.16.0-1.2ubuntu4.1 [109 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.1 [5,886 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmythes-1.2-0 amd64 2:1.2.4-4build1 [9,352 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-parser-0.17-0 amd64 0.17.2-2 [107 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-0.17-0 amd64 0.17.2-2 [393 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4 [172 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmhash2 amd64 0.9.9.9-9build2 [95.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 librasqal3 amd64 0.9.33-0.2ubuntu1 [193 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 librdf0 amd64 1.0.17-1.1ubuntu3 [106 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu7 [209 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-nss amd64 1.2.33-1build2 [67.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-core amd64 1:7.3.7-0ubuntu0.22.04.4 [40.4 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.4 [974 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base-drivers amd64 1:7.3.7-0ubuntu0.22.04.4 [602 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base amd64 1:7.3.7-0ubuntu0.22.04.4 [1,725 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.3 [595 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.21+9-0ubuntu1~22.04 [214 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common-doc all 3.0.8.33535.ds4-1ubuntu2 [26.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common all 3.0.8.33535.ds4-1ubuntu2 [15.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtommath1 amd64 1.2.0-6ubuntu0.22.04.1 [56.5 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfbclient2 amd64 3.0.8.33535.ds4-1ubuntu2 [512 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libib-util amd64 3.0.8.33535.ds4-1ubuntu2 [3,378 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-server-core amd64 3.0.8.33535.ds4-1ubuntu2 [2,533 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-utils amd64 3.0.8.33535.ds4-1ubuntu2 [872 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-dejavu all 2.37-2build1 [3,192 B]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation2 all 2.1.5-1 [1,614 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-linuxlibertine all 5.3.0-6 [1,627 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-noto-extra all 20201225-1build1 [72.4 MB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-ui-core all 20201225-1build1 [1,420 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium all 20081126:1.03-4 [245 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium-basic all 1.102-1.1 [384 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphene-1.0-0 amd64 1.10.8-1 [48.2 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.1 [204 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gl amd64 1.20.1-1ubuntu0.1 [125 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gtk3 amd64 1.20.3-0ubuntu1.1 [33.2 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbsh-java all 2.0b4-20 [289 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdr-0.1-1 amd64 0.1.6-2build2 [392 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libel-api-java all 3.0.0-3 [64.9 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 libetonyek-0.1-1 amd64 0.1.10-3build1 [637 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfreehand-0.1-1 amd64 0.1.2-3build2 [272 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet-api-java all 4.0.1-2 [81.0 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjsp-api-java all 2.3.4-3 [53.7 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwebsocket-api-java all 1.1-2 [40.1 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet3.1-java all 1:4.0.1-2 [9,276 B]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhsqldb1.8.0-java all 1.8.0.10+dfsg-11 [765 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunoloader-java all 1:7.3.7-0ubuntu0.22.04.4 [12.8 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure-java amd64 1:7.3.7-0ubuntu0.22.04.4 [83.4 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liblibreoffice-java all 1:7.3.7-0ubuntu0.22.04.4 [1,604 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmspub-0.1-1 amd64 0.1.4-3build3 [144 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmwaw-0.3-3 amd64 0.3.21-1build1 [2,375 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libodfgen-0.1-1 amd64 0.1.8-2build2 [245 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpagemaker-0.0-0 amd64 0.0.4-1build3 [55.9 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/main amd64 lp-solve amd64 5.5.2.5-2build2 [315 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-calc amd64 1:7.3.7-0ubuntu0.22.04.4 [8,426 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisio-0.1-1 amd64 0.1.7-1build5 [238 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpd-0.10-10 amd64 0.10.3-2build1 [209 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpg-0.3-3 amd64 0.3.3-1build3 [49.9 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-draw amd64 1:7.3.7-0ubuntu0.22.04.4 [3,228 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-impress amd64 1:7.3.7-0ubuntu0.22.04.4 [1,359 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.4 [597 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder-bin amd64 1:7.3.7-0ubuntu0.22.04.4 [971 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.4 [10.3 MB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-uno amd64 1:7.3.7-0ubuntu0.22.04.4 [148 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice amd64 1:7.3.7-0ubuntu0.22.04.4 [12.9 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gnome amd64 1:7.3.7-0ubuntu0.22.04.4 [72.9 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gtk3 amd64 1:7.3.7-0ubuntu0.22.04.4 [509 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-java-common all 1:7.3.7-0ubuntu0.22.04.4 [621 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder all 1:7.3.7-0ubuntu0.22.04.4 [2,112 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-bsh all 1:7.3.7-0ubuntu0.22.04.4 [42.3 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-js all 1:7.3.7-0ubuntu0.22.04.4 [645 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-python all 1:7.3.7-0ubuntu0.22.04.4 [16.5 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-firebird amd64 1:7.3.7-0ubuntu0.22.04.4 [176 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-hsqldb amd64 1:7.3.7-0ubuntu0.22.04.4 [135 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-mysql amd64 1:7.3.7-0ubuntu0.22.04.4 [123 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-postgresql amd64 1:7.3.7-0ubuntu0.22.04.4 [279 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-elementary all 1:7.3.7-0ubuntu0.22.04.4 [8,020 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-yaru all 1:7.3.7-0ubuntu0.22.04.4 [3,760 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-wiki-publisher all 1.2.0+LibO7.3.7-0ubuntu0.22.04.4 [7,918 B]
# Get:128 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-nlpsolver all 0.9+LibO7.3.7-0ubuntu0.22.04.4 [7,974 B]
# Fetched 227 MB in 4s (51.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 121730 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../002-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../003-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../004-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../005-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../006-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../007-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../008-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../009-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../010-ure_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../011-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../012-libabsl20210324_0~20210324.2-2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../013-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../014-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../015-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../016-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../017-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../018-libgpgme11_1.16.0-1.2ubuntu4.1_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.1) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../019-libgpgmepp6_1.16.0-1.2ubuntu4.1_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../020-libharfbuzz-icu0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../021-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../022-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../023-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../024-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../025-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../026-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../027-libraptor2-0_2.0.15-0ubuntu4_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../028-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../029-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../030-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../031-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../032-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../033-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../034-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../035-libreoffice-base-core_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-base-drivers.
# Preparing to unpack .../036-libreoffice-base-drivers_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-base.
# Preparing to unpack .../037-libreoffice-base_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/dialog.xlc to /usr/lib/libreoffice/share/basic/dialog.xlc.noaccess by libreoffice-base', none removed.
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/script.xlc to /usr/lib/libreoffice/share/basic/script.xlc.noaccess by libreoffice-base', none removed.
# Unpacking libreoffice-base (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../038-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../039-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../040-apparmor_3.0.4-2ubuntu2.3_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.3) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../041-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../042-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../043-openjdk-11-jre_11.0.21+9-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.21+9-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../044-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../045-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package firebird3.0-common-doc.
# Preparing to unpack .../046-firebird3.0-common-doc_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-common.
# Preparing to unpack .../047-firebird3.0-common_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libtommath1:amd64.
# Preparing to unpack .../048-libtommath1_1.2.0-6ubuntu0.22.04.1_amd64.deb ...
# Unpacking libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Selecting previously unselected package libfbclient2:amd64.
# Preparing to unpack .../049-libfbclient2_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libib-util:amd64.
# Preparing to unpack .../050-libib-util_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-server-core:amd64.
# Preparing to unpack .../051-firebird3.0-server-core_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-utils.
# Preparing to unpack .../052-firebird3.0-utils_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../053-fonts-crosextra-caladea_20130214-2.1_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2.1) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../054-fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../055-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../056-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../057-fonts-dejavu_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu (2.37-2build1) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../058-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../059-fonts-linuxlibertine_5.3.0-6_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-6) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../060-fonts-noto-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-core (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-extra.
# Preparing to unpack .../061-fonts-noto-extra_20201225-1build1_all.deb ...
# Unpacking fonts-noto-extra (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../062-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-ui-core.
# Preparing to unpack .../063-fonts-noto-ui-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-ui-core (20201225-1build1) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../064-fonts-sil-gentium_20081126%3a1.03-4_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-4) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../065-fonts-sil-gentium-basic_1.102-1.1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1.1) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../066-libgraphene-1.0-0_1.10.8-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../067-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../068-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.1_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.1) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../069-gstreamer1.0-gl_1.20.1-1ubuntu0.1_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.1) ...
# Selecting previously unselected package gstreamer1.0-gtk3:amd64.
# Preparing to unpack .../070-gstreamer1.0-gtk3_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../071-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../072-libabw-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../073-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../074-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../075-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../076-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../077-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../078-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libbsh-java.
# Preparing to unpack .../079-libbsh-java_2.0b4-20_all.deb ...
# Unpacking libbsh-java (2.0b4-20) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../080-libcdr-0.1-1_0.1.6-2build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../081-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../082-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../083-libe-book-0.1-1_0.1.3-2build2_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Selecting previously unselected package libel-api-java.
# Preparing to unpack .../084-libel-api-java_3.0.0-3_all.deb ...
# Unpacking libel-api-java (3.0.0-3) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../085-libepubgen-0.1-1_0.1.1-1ubuntu5_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../086-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../087-libfreehand-0.1-1_0.1.2-3build2_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-3build2) ...
# Selecting previously unselected package libservlet-api-java.
# Preparing to unpack .../088-libservlet-api-java_4.0.1-2_all.deb ...
# Unpacking libservlet-api-java (4.0.1-2) ...
# Selecting previously unselected package libjsp-api-java.
# Preparing to unpack .../089-libjsp-api-java_2.3.4-3_all.deb ...
# Unpacking libjsp-api-java (2.3.4-3) ...
# Selecting previously unselected package libwebsocket-api-java.
# Preparing to unpack .../090-libwebsocket-api-java_1.1-2_all.deb ...
# Unpacking libwebsocket-api-java (1.1-2) ...
# Selecting previously unselected package libservlet3.1-java.
# Preparing to unpack .../091-libservlet3.1-java_1%3a4.0.1-2_all.deb ...
# Unpacking libservlet3.1-java (1:4.0.1-2) ...
# Selecting previously unselected package libhsqldb1.8.0-java.
# Preparing to unpack .../092-libhsqldb1.8.0-java_1.8.0.10+dfsg-11_all.deb ...
# Unpacking libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Selecting previously unselected package libunoloader-java.
# Preparing to unpack .../093-libunoloader-java_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libunoloader-java (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package ure-java.
# Preparing to unpack .../094-ure-java_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking ure-java (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package liblibreoffice-java.
# Preparing to unpack .../095-liblibreoffice-java_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../096-libmspub-0.1-1_0.1.4-3build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../097-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../098-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../099-libpagemaker-0.0-0_0.0.4-1build3_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../100-lp-solve_5.5.2.5-2build2_amd64.deb ...
# Unpacking lp-solve (5.5.2.5-2build2) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../101-libwps-0.4-4_0.4.12-2build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../102-libreoffice-calc_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-calc (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../103-libvisio-0.1-1_0.1.7-1build5_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../104-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../105-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../106-libreoffice-draw_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-draw (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../107-libreoffice-impress_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-impress (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../108-libreoffice-math_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-math (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-report-builder-bin.
# Preparing to unpack .../109-libreoffice-report-builder-bin_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../110-libreoffice-writer_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-writer (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../111-python3-uno_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice.
# Preparing to unpack .../112-libreoffice_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-gnome.
# Preparing to unpack .../113-libreoffice-gnome_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-gtk3.
# Preparing to unpack .../114-libreoffice-gtk3_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-java-common.
# Preparing to unpack .../115-libreoffice-java-common_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-report-builder.
# Preparing to unpack .../116-libreoffice-report-builder_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-script-provider-bsh.
# Preparing to unpack .../117-libreoffice-script-provider-bsh_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-script-provider-js.
# Preparing to unpack .../118-libreoffice-script-provider-js_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-script-provider-python.
# Preparing to unpack .../119-libreoffice-script-provider-python_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-sdbc-firebird.
# Preparing to unpack .../120-libreoffice-sdbc-firebird_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-sdbc-hsqldb.
# Preparing to unpack .../121-libreoffice-sdbc-hsqldb_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-sdbc-mysql.
# Preparing to unpack .../122-libreoffice-sdbc-mysql_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-sdbc-postgresql.
# Preparing to unpack .../123-libreoffice-sdbc-postgresql_1%3a7.3.7-0ubuntu0.22.04.4_amd64.deb ...
# Unpacking libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-style-elementary.
# Preparing to unpack .../124-libreoffice-style-elementary_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-style-yaru.
# Preparing to unpack .../125-libreoffice-style-yaru_1%3a7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-wiki-publisher.
# Preparing to unpack .../126-libreoffice-wiki-publisher_1.2.0+LibO7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.4) ...
# Selecting previously unselected package libreoffice-nlpsolver.
# Preparing to unpack .../127-libreoffice-nlpsolver_0.9+LibO7.3.7-0ubuntu0.22.04.4_all.deb ...
# Unpacking libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.4) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up fonts-sil-gentium-basic (1.102-1.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Setting up fonts-noto-extra (20201225-1build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libel-api-java (3.0.0-3) ...
# Setting up openjdk-11-jre:amd64 (11.0.21+9-0ubuntu1~22.04) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.1) ...
# Setting up firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Setting up firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up apparmor (3.0.4-2ubuntu2.3) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up fonts-sil-gentium (20081126:1.03-4) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up libwebsocket-api-java (1.1-2) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libfreehand-0.1-1 (0.1.2-3build2) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2) ...
# Setting up fonts-linuxlibertine (5.3.0-6) ...
# Setting up libbsh-java (2.0b4-20) ...
# Setting up libjsp-api-java (2.3.4-3) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up libservlet-api-java (4.0.1-2) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up fonts-crosextra-caladea (20130214-2.1) ...
# Setting up libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libunoloader-java (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up fonts-noto-ui-core (20201225-1build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up fonts-noto-core (20201225-1build1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.4) ...
# Setting up libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Setting up libservlet3.1-java (1:4.0.1-2) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Setting up libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up fonts-dejavu (2.37-2build1) ...
# Setting up libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.1) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Setting up lp-solve (5.5.2.5-2build2) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up ure-java (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-math (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/math.xcd with new version
# Setting up libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/postgresql.xcd with new version
# Setting up liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-draw (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/draw.xcd with new version
#
# Creating config file /etc/libreoffice/registry/graphicfilter.xcd with new version
# Setting up libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/gnome.xcd with new version
# Setting up libreoffice-impress (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/impress.xcd with new version
#
# Creating config file /etc/libreoffice/registry/ogltrans.xcd with new version
# Setting up libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Setting up libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-calc (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/calc.xcd with new version
# Setting up libreoffice-base (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/base.xcd with new version
# Setting up libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-writer (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/writer.xcd with new version
# Setting up libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice (1:7.3.7-0ubuntu0.22.04.4) ...
# Setting up libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.4) ...
#
# Creating config file /etc/libreoffice/registry/reportbuilder.xcd with new version
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for dictionaries-common (1.28.14) ...

# %% [markdown]
# ### **AS RETRIVER FUNCTION CALL**
# <b> - Vectorstore will have  documents in form of meaningful vectors or embeddings organised and stored so that search of relevant documents are easier</b><br>
# <b> - From database to retrive only relevant documents is possible in as_retriver() function which has 2 search types
# - search_type: How to select the chunks from the vector store. It has two types: similarity and MMR. Similarity means selecting the most similar chunks to the query. MMR also does similarity searches. The difference is that MMR will diversify the selected chunks rather than return a very closed result.
#
# Eg:
#
#
# 1. **Similarity Selection**:
#     - Imagine you have a collection of news articles about animals.
#     - When you search for "tigers," similarity selection will return articles that closely match the query. These might include:
#         - "Tiger conservation efforts in India."
#         - "Bengal tigers spotted in a national park."
#         - "Tiger behavior and hunting patterns."
#     - The focus is on finding articles directly related to tigers.
#
# 2. **MMR (Maximal Marginal Relevance)**:
#     - Now, let's use MMR.
#     - Instead of stopping at the most similar articles, MMR aims for diversity.
#     - It might add articles like:
#         - "Lions: Cousins of Tigers" (related but different).
#         - "Endangered Big Cats Worldwide" (adding variety).
#     - MMR balances relevance with a broader perspective.
#
# In summary, similarity search finds close matches, while MMR ensures a mix of relevant and diverse chunks.
#
# - search_kwargs.k: Which defines the number of chunks to be selected.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from langchain_community.document_loaders import Docx2txtLoader,UnstructuredWordDocumentLoader
from langchain.document_loaders import DirectoryLoader
#loader = UnstructuredWordDocumentLoader("/content/content/MyDrive/Sample Job/05-01-23_Francis_Bryanna_ROR.docx")
#loader = UnstructuredWordDocumentLoader("/content/content/MyDrive/Sample Job/*.doc*")
loader = DirectoryLoader('/content/content/MyDrive/Sample Job/', glob="*.doc*", show_progress=True,loader_cls=UnstructuredWordDocumentLoader)
data = loader.load()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s][nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# 100%|██████████| 47/47 [01:39<00:00,  2.11s/it]

# %%
#data[0]

# %%
#data[0].metadata["source"].split("/")[-1]

# %%
# Instantiate the parser with the new model.
import os
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate,SystemMessagePromptTemplate
from langchain.chat_models import ChatOpenAI

from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
from typing import List
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
# os.environ["HUGGINGFACEHUB_API_TOKEN"] ="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"
# #os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

class Patient(BaseModel):
    title: str = Field(description="File name  if found else say null.Dont assume title.")
    email: str = Field(description="Email of patient if present in document else say null")
    name: str=Field(description="Full name of patient if present else say null")
    firstnamepatient: str = Field(description="First name of the patient.")
    lastnamepatient: str= Field(description="Last name of the patient")
    middlename: str= Field(description="Patient middle initial if any else leave blank")
    ssn: str= Field(description="Social security number of patient or SSN number of patient if present else return as null.Do not make up any answer.The number if present should be shown mandatorily.Any kind of hallucinated answer is strictly avoided.Give null if not present")
    doctor: str = Field(description="Treating Doctor name is shown with prefixed DR. Dont return any other name in document which doesnt start with DR.")
    dob: str = Field(description="date of birth in format mm/dd/yyyy")
    dol: str = Field(description="Date of loss/issse or DOL or DOI annotated  mm/dd/yyyy if present only else show as  null ")
    dos: str=Field(description="Date of service or DOS annoted ")
    claimno: str=Field(description="Claim No of the ROR")
    gender: str=Field(description="Gender of patient say it is F for female and M for male only if it is explicitly mentioned in document else say null dont assume gender at any cost. This should not be assumed at any cost it is optional if document doesnt have explicit details on gender of patient dont fill this in json")
    bodyparts: List[str]=Field(description="Body parts .Relavant body parts to be listed only every listed element is body part of that person who is injured as per document.Dont assume at any cost say null if not known")




parser = PydanticOutputParser(pydantic_object=Patient)
llm = HuggingFaceHub(repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1", model_kwargs={"temperature": 0.1, "max_length": 1000, "max_new_tokens": 700})
# Update the prompt to match the new query and desired format.
prompt = ChatPromptTemplate(
    messages=[
        HumanMessagePromptTemplate.from_template(
            "answer the users question as best as possible.\n{format_instructions}\n{question}"
        )
    ],
    input_variables=["question"],
    partial_variables={
        "format_instructions": parser.get_format_instructions(),
    },
)
import re
import json

def extract_json_from_string(input_string):

    json_pattern = re.compile(r'\{(?:[^{}]|)*\}')


    json_matches = json_pattern.findall(input_string)


    extracted_json = [json.loads(match) for match in json_matches]

    return extracted_json

# %%
document_query = "Create a JSON response based on description"+data[0].page_content+" Filename:"+data[0].metadata["source"].split("/")[-1]

ask=prompt | llm
output=ask.invoke({"question":document_query})
print(output)

p=extract_json_from_string(output)
print(p)
# Out:
# x
#
# JSON:
# {
#   "title": "05-26-23_Avila_Marco_ROR.docx",
#   "email": null,
#   "name": "AVILA, MARCO",
#   "firstnamepatient": "MARCO",
#   "lastnamepatient": "AVILA",
#   "middlename": null,
#   "ssn": null,
#   "doctor": "DR. ENSALADA",
#   "dob": "06.25.1968",
#   "dol": "July 2021",
#   "dos": "05.26.23",
#   "claimno": null,
#   "gender": null,
#   "bodyparts": ["knee"]
# }
# [{'title': '05-26-23_Avila_Marco_ROR.docx', 'email': None, 'name': 'AVILA, MARCO', 'firstnamepatient': 'MARCO', 'lastnamepatient': 'AVILA', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '06.25.1968', 'dol': 'July 2021', 'dos': '05.26.23', 'claimno': None, 'gender': None, 'bodyparts': ['knee']}]

# %%
for i in range(len(data)):
  print("doc no"+str(i))
  print(data[i].metadata["source"].split("/")[-1])
  print(len(data[i].page_content))

  document_query = "Create a JSON based on this description: " + data[i].page_content+" Filename:"+data[i].metadata["source"].split("/")[-1]

  llm = HuggingFaceHub(repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1", model_kwargs={"temperature": 0.1, "max_length": 500, "max_new_tokens": 1000})
  from langchain.prompts import PromptTemplate


  chain = prompt | llm


  output=chain.invoke({"question":document_query })

  print(extract_json_from_string(output))
  #print(len(chain.invoke({"question":document_query })))
# Out:
# doc no0
# 05-26-23_Avila_Marco_ROR.doc
# 15397
# [{'title': '05-26-23_Avila_Marco_ROR.docx', 'email': None, 'name': 'AVILA, MARCO', 'firstnamepatient': 'MARCO', 'lastnamepatient': 'AVILA', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '06.25.1968', 'dol': 'July 2021', 'dos': '05.26.23', 'claimno': None, 'gender': None, 'bodyparts': ['knee', 'penis']}]
# doc no1
# 05-27-23_Huffman_Andi_ROR.doc
# 3791
# [{'title': '05-27-23_Huffman_Andi_ROR.docx', 'email': None, 'name': 'HUFFMAN, ANDI', 'firstnamepatient': 'ANDI', 'lastnamepatient': 'HUFFMAN', 'middlename': None, 'ssn': None, 'doctor': 'Daniel S. Sharp, M.D.', 'dob': '10.11.1976', 'dol': '07.18.2022', 'dos': '05.29.23', 'claimno': '202220914', 'gender': None, 'bodyparts': ['right shoulder']}]
# doc no2
# 05-27-23_Lytle_Erin_ROR.doc
# 23921
# [{'title': '05-27-23_Lytle_Erin_ROR.docx', 'email': None, 'name': 'LYTLE, ERIN', 'firstnamepatient': 'ERIN', 'lastnamepatient': 'LYTLE', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '01.30.1981', 'dol': '03.20.2021', 'dos': '05.29.23', 'claimno': '202105640', 'gender': None, 'bodyparts': ['back', 'thoracic spine', 'lumbar spine']}, {'title': '05-27-23_Lytle_Erin_ROR.docx', 'email': None, 'name': 'LYTLE, ERIN', 'firstnamepatient': 'ERIN', 'lastnamepatient': 'LYTLE', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '01.30.1981', 'dol': '03.20.2021', 'dos': '05.29.23', 'claimno': '202105640', 'gender': None, 'bodyparts': ['back', 'thoracic spine', 'lumbar spine']}]
# doc no3
# 05-31-23_Melvin_Marcus_ROR.doc
# 26628
# [{'title': '05-31-23_Melvin_Marcus_ROR.docx', 'email': None, 'name': 'MELVIN, MARCUS', 'firstnamepatient': 'Marcus', 'lastnamepatient': 'Melvin', 'middlename': None, 'ssn': None, 'doctor': 'S2T', 'dob': '01.11.1982', 'dol': '08.08.2022', 'dos': '08.08.2022', 'claimno': '202215411', 'gender': None, 'bodyparts': ['abdomen', 'back']}]
# doc no4
# 05-23-23_Estrada Ramirez_Jesus_ROR.doc
# 29784
# [{'title': '05-23-23_Estrada Ramirez_Jesus_ROR.docx', 'email': None, 'name': 'ESTRADA RAMIREZ, JESUS', 'firstnamepatient': 'JESUS', 'lastnamepatient': 'ESTRADA RAMIREZ', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '06.21.1974', 'dol': '02.14.2022', 'dos': '05.23.23', 'claimno': '000706-046636-WC-01', 'gender': None, 'bodyparts': ['hindfoot', 'heel', 'ankle', 'subtalar joint']}]
# doc no5
# 05-19-23_Crockett_Cindy_ROR.doc
# 25475
# [{'title': '05-19-23_Crockett_Cindy_ROR.docx', 'email': None, 'name': 'CROCKETT, CINDY', 'firstnamepatient': 'Cindy', 'lastnamepatient': 'Crockett', 'middlename': None, 'ssn': None, 'doctor': 'Dr. ENSALADA', 'dob': '05.13.1965', 'dol': '01.16.2023', 'dos': None, 'claimno': '202301833', 'gender': None, 'bodyparts': ['neck', 'mid and low back']}]
# doc no6
# 05-27-23_Cunningham_Melanie_ROR.doc
# 11261
# [{'title': '05-27-23_Cunningham_Melanie_ROR.docx', 'email': None, 'name': 'CUNNINGHAM, MELANIE', 'firstnamepatient': 'MELANIE', 'lastnamepatient': 'CUNNINGHAM', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '10.22.1961', 'dol': '01.09.2023', 'dos': '05.29.23', 'claimno': '20231149', 'gender': None, 'bodyparts': ['right bicep area', 'right bicep', 'right mid bicep', 'right upper extremity', 'right shoulder', 'long head of biceps', 'rotator cuff', 'supraspinatus tendon', 'acromioclavicular joint']}]
# doc no7
# 05-22-23_Kriger_Sandra_ROR.doc
# 6177
# []
# doc no8
# 05-19-23_Bryan_Meagan_ROR.doc
# 50380
# [{'title': 'Bryan, Meagan', 'email': None, 'name': 'Bryan, Meagan', 'firstnamepatient': 'Meagan', 'lastnamepatient': 'Bryan', 'middlename': None, 'ssn': None, 'doctor': 'S2T', 'dob': '05.19.1981', 'dol': '01.30.2023', 'dos': '05.19.23', 'claimno': None, 'gender': None, 'bodyparts': ['knee']}]
# doc no9
# 05-06-23_Charles_Erilene_ROR.doc
# 51119
# []
# doc no10
# 05-26-23_Dawwas_Mohammed_ROR.doc
# 11382
# [{'title': '05-26-23_Dawwas_Mohammed_ROR.docx', 'email': None, 'name': 'DAWWAS, MOHAMMED', 'firstnamepatient': 'MOHAMMED', 'lastnamepatient': 'DAWWAS', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '05.24.1999', 'dol': '08.26.2022', 'dos': '05.26.23', 'claimno': '1000056003', 'gender': 'M', 'bodyparts': ['back', 'shoulder', 'upper back', 'thorax', 'periscapular region', 'hands', 'heel', 'low back']}]
# doc no11
# 05-19-23_Kriger_Sandra_ROR.doc
# 4857
# [{'title': '05-19-23_Kriger_Sandra_ROR.docx', 'email': None, 'name': 'KRIGER, SANDRA', 'firstnamepatient': 'SANDRA', 'lastnamepatient': 'KRIGER', 'middlename': None, 'ssn': None, 'doctor': 'Mariya Nikolaeva, PA-C. (Intermountain WorkMed – Ogden)', 'dob': '09.20.1959', 'dol': '11.21.2022', 'dos': '05.19.23', 'claimno': '20222683', 'gender': None, 'bodyparts': ['right shoulder']}]
# doc no12
# 05-10-23_Rodriguez_Jose_ROR.doc
# 8074
# [{'title': '05-10-23_Rodriguez_Jose_ROR.docx', 'email': None, 'name': 'Rodriguez, Jose', 'firstnamepatient': 'Jose', 'lastnamepatient': 'Rodriguez', 'middlename': None, 'ssn': None, 'doctor': 'DR. NEWTON', 'dob': '07/09/1965', 'dol': None, 'dos': '4/28/23', 'claimno': 'WCCW21008160', 'gender': None, 'bodyparts': ['back', 'neck', 'thigh', 'eye', 'hip']}]
# doc no13
# 05-15-23_Read_Ryan_ROR.doc
# 81068
# [{'title': 'Read, Ryan', 'email': None, 'name': 'READ, RYAN', 'firstnamepatient': 'Ryan', 'lastnamepatient': 'Read', 'middlename': None, 'ssn': '123-45-6789', 'doctor': 'S2T', 'dob': '12/10/1981', 'dol': '10/17/2022', 'dos': '05/13/2023', 'claimno': '202300837', 'gender': 'M', 'bodyparts': ['lumbar spine', 'cervical spine', 'thoracic back', 'leg', 'ankle']}]
# doc no14
# 05-11-23_Ferrer_Miriam Francisca A_ROR.doc
# 8152
# [{'title': '05-11-23_Ferrer_Miriam Francisca A_ROR.docx', 'email': None, 'name': 'FERRER, MIRIAM FRANCISCA A.', 'firstnamepatient': 'MIRIAM', 'lastnamepatient': 'FERRER', 'middlename': 'FRANCISCA', 'ssn': None, 'doctor': 'Travis J. Jones, M.D. (Utah Orthopaedic Specialists LLC)', 'dob': '12.02.1954', 'dol': '12.07.2022', 'dos': '05.11.23', 'claimno': '001627-184366-WC-01', 'gender': 'F', 'bodyparts': ['left foot', 'left tibia', 'left fibula', 'left ankle']}]
# doc no15
# 05-17-23_Manwaring_Joshua_ROR.doc
# 11353
# [{'title': '05-17-23_Manwaring_Joshua_ROR.docx', 'email': None, 'name': 'MANWARING, JOSHUA', 'firstnamepatient': 'JOSHUA', 'lastnamepatient': 'MANWARING', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '04.14.1982', 'dol': '03.20.2022', 'dos': 'DR. ENSALADA', 'claimno': '1691-WC-22-03300589', 'gender': None, 'bodyparts': ['knee']}]
# doc no16
# 05-16-23_Loftus_Brian_ROR.doc
# 2800
# [{'title': '05-16-23_Loftus_Brian_ROR.docx', 'email': None, 'name': 'LOFTUS, BRIAN', 'firstnamepatient': 'BRIAN', 'lastnamepatient': 'LOFTUS', 'middlename': None, 'ssn': None, 'doctor': ['Duy Tran, D.C.', 'Not available', 'Not available', 'Ashlynn M. Martinez, P.A.-C.'], 'dob': '03.24.1983', 'dol': '02.09.2023', 'dos': ['05.16.23', '02.09.2023', '02.09.2023', '02.28.2023'], 'claimno': '2240459082', 'gender': None, 'bodyparts': ['thoracic spine', 'lumbar spine', 'back', 'thoracic spine', 'lumbar spine', 'back', 'mid and lower back', 'right leg', 'thoracic spine', 'lumbar spine']}]
# doc no17
# 05-17-23_Hughes_Sharyn_ROR.doc
# 10817
# [{'title': '05-17-23_Hughes_Sharyn_ROR.docx', 'email': None, 'name': 'HUGHES, SHARYN', 'firstnamepatient': 'SHARYN', 'lastnamepatient': 'HUGHES', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA, DR. LARCOM, DR. TSAI, DR. BURICK, DR. DEPOLA, DR. LARCOM', 'dob': '07.16.1969', 'dol': '10.28.2022', 'dos': '05.17.23', 'claimno': '004138-140348-WC-01', 'gender': None, 'bodyparts': ['right upper extremity', 'right humerus', 'right elbow', 'right shoulder']}]
# doc no18
# 05-13-23_Gomez_Jose_ROR.doc
# 37913
# [{'title': 'Gomez, Jose', 'email': None, 'name': 'Gomez, Jose', 'firstnamepatient': 'Jose', 'lastnamepatient': 'Gomez', 'middlename': None, 'ssn': '123-45-6789', 'doctor': 'Dr. ENSALADA', 'dob': '12/24/1983', 'dol': '09/12/2022', 'dos': 'February 22, 2019', 'claimno': '202217961, 201903965', 'gender': 'M', 'bodyparts': ['hip', 'lower back']}]
# doc no19
# 05-19-23_Perez_Teara_ROR.doc
# 37810
# [{'title': 'Perez, Teara', 'email': None, 'name': 'Perez, Teara', 'firstnamepatient': 'Teara', 'lastnamepatient': 'Perez', 'middlename': None, 'ssn': None, 'doctor': 'Dr. ENSALADA', 'dob': '06.28.1991', 'dol': '12.10.2022', 'dos': None, 'claimno': '22-089593', 'gender': None, 'bodyparts': ['head', 'neck', 'back', 'shoulder']}]
# doc no20
# 05-10-23_Carrier_Benjamin_ROR.doc
# 10110
# [{'title': '05-10-23_Carrier_Benjamin_ROR.docx', 'email': None, 'name': 'Carrier, Benjamin', 'firstnamepatient': 'Benjamin', 'lastnamepatient': 'Carrier', 'middlename': None, 'ssn': None, 'doctor': 'Edwin Haronian, M.D.', 'dob': '07/10/1968', 'dol': '04/01/2022', 'dos': '05/09/2023', 'claimno': '2080395152', 'gender': 'M', 'bodyparts': ['R shoulder', 'neck']}]
# doc no21
# 05-15-23_Kemp_Maxwell_ROR.doc
# 21602
# [{'title': '05-15-23_Kemp_Maxwell_ROR.docx', 'email': None, 'name': 'KEMP, MAXWELL', 'firstnamepatient': 'MAXWELL', 'lastnamepatient': 'KEMP', 'middlename': None, 'ssn': None, 'doctor': None, 'dob': '06.11.1999', 'dol': '07.02.2020', 'dos': None, 'claimno': '202209375', 'gender': None, 'bodyparts': ['back', 'chest', 'lungs', 'thoracic paraspinous muscles']}]
# doc no22
# 05-10-23_Mathis_Jesse_ROR.doc
# 45833
# [{'title': 'Mathis, Jesse', 'email': None, 'name': None, 'firstnamepatient': 'Jesse', 'lastnamepatient': 'Mathis', 'middlename': None, 'ssn': None, 'doctor': 'Dr. NEWTON', 'dob': '08/04/1960', 'dol': '06/25/2019', 'dos': '05/09/2023', 'claimno': '030051-034774-WC-01', 'gender': 'M', 'bodyparts': ['neck', 'shoulders', 'upper and lower back', 'hips', 'knees', 'head', 'brain', 'heart', 'cardiovascular system']}]
# doc no23
# 05-16-23_Navarro_Rolando_ROR.doc
# 7277
# [{'title': '05-16-23_Navarro_Rolando_ROR.docx', 'email': None, 'name': 'NAVARRO, ROLANDO', 'firstnamepatient': 'ROLANDO', 'lastnamepatient': 'NAVARRO', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '04.03.1988', 'dol': '12.15.2022', 'dos': 'DR. ENSALADA', 'claimno': '1262WC220300162', 'gender': None, 'bodyparts': ['hand', 'left ring finger metacarpal']}]
# doc no24
# 05-11-23_Emond_Carolyn_ROR.doc
# 18315
# [{'title': '05-11-23_Emond_Carolyn_ROR.docx', 'email': None, 'name': 'EMOND, CAROLYN', 'firstnamepatient': 'CAROLYN', 'lastnamepatient': 'EMOND', 'middlename': None, 'ssn': None, 'doctor': 'S2T', 'dob': '09.03.1967', 'dol': '04.29.2022/10.01.2022', 'dos': '05.11.23', 'claimno': '202224994', 'gender': None, 'bodyparts': ['neck', 'upper back', 'head', 'thoracic spine', 'cervical spine', 'hands', 'bilateral upper extremities', 'right hip', 'left hip']}]
# doc no25
# 05-10-23_Contreras_Ivonne_ROR.doc
# 14223
# [{'title': '05-10-23_Contreras_Ivonne_ROR.docx', 'email': None, 'name': 'Contreras, Ivonne', 'firstnamepatient': 'Ivonne', 'lastnamepatient': 'Contreras', 'middlename': None, 'ssn': None, 'doctor': 'Dr. Mattar', 'dob': '06/01/1973', 'dol': '02/05/2021', 'dos': '05/09/2023', 'claimno': '402106GF58G-0001', 'gender': None, 'bodyparts': ['back', 'right leg']}]
# doc no26
# 05-10-23_Delgado Tovar_Norma_ROR.doc
# 13466
# [{'title': '05-10-23_Delgado Tovar_Norma_ROR.docx', 'email': None, 'name': 'Delgado Tovar, Norma', 'firstnamepatient': 'Norma', 'lastnamepatient': 'Delgado Tovar', 'middlename': None, 'ssn': None, 'doctor': 'Dr. NEWTON', 'dob': '10/10/1989', 'dol': None, 'dos': '05/09/23', 'claimno': '158-CB-FJA3628-A', 'gender': None, 'bodyparts': ['Neck pain', 'radiating to shoulder', 'occasional numbness of hands', 'LBP', 'difficulties with movements', 'numbness and tingling of BI legs', 'BI hand pain', 'with numbness and weakness']}]
# doc no27
# 05-17-23_Mathews_Derek_ROR.doc
# 8454
# [{'title': '05-17-23_Mathews_Derek_ROR.docx', 'email': None, 'name': 'MATHEWS, DEREK', 'firstnamepatient': 'DEREK', 'lastnamepatient': 'MATHEWS', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '03/01/1983', 'dol': '11/29/2022', 'dos': '05/17/23', 'claimno': '202224020', 'gender': 'M', 'bodyparts': ['right finger', 'right hand', 'right hand joint', 'right ring finger', 'right middle finger', 'proximal phalanx of the right fourth digit', 'right fourth digit', 'right hand pain']}]
# doc no28
# 05-16-23_Galvan_Raul_ROR.doc
# 78047
# [{'title': 'GALVAN, RAUL', 'email': None, 'name': 'GALVAN, RAUL', 'firstnamepatient': 'RAUL', 'lastnamepatient': 'GALVAN', 'middlename': None, 'ssn': None, 'doctor': None, 'dob': '10.30.1946', 'dol': '04.22.2022', 'dos': None, 'claimno': None, 'gender': None, 'bodyparts': ['hand', 'finger']}]
# doc no29
# 05-17-23_Galbraith_Caleb_ROR.doc
# 5039
# [{'title': '05-17-23_Galbraith_Caleb_ROR.docx', 'email': None, 'name': 'GALBRAITH, CALEB', 'firstnamepatient': 'CALEB', 'lastnamepatient': 'GALBRAITH', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA, DR. BRETT E. RICHARDS, DR. BRETT MARTINDALE, CASEY JOHNSTON, P.A.-C.', 'dob': '08/22/1989', 'dol': '10.11.2022', 'dos': '05.17.23', 'claimno': '695508-1', 'gender': 'M', 'bodyparts': ['left thumb']}]
# doc no30
# 05-13-23_Meiner_Rajan_ROR.doc
# 12431
# [{'title': '05-13-23_Meiner_Rajan_ROR.docx', 'email': None, 'name': 'MEINER, RAJAN', 'firstnamepatient': 'RAJAN', 'lastnamepatient': 'MEINER', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '06.01.1955', 'dol': '06.28.2022', 'dos': '05.13.23', 'claimno': '202212366', 'gender': None, 'bodyparts': ['left ankle']}]
# doc no31
# 05-16-23_Hepworth_Tiffany_ROR.doc
# 20622
# [{'title': '05-16-23_Hepworth_Tiffany_ROR.docx', 'email': None, 'name': 'HEPWORTH, TIFFANY', 'firstnamepatient': 'TIFFANY', 'lastnamepatient': 'HEPWORTH', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '12.19.1981', 'dol': '12.30.2022', 'dos': '05.16.23', 'claimno': 'W074992684', 'gender': None, 'bodyparts': ['low back', 'right posterior thigh', 'right calf', 'right lower extremity', 'right knee', 'right thigh', 'left proximal lower extremity', 'perineal region']}]
# doc no32
# 05-09-23_Johnson_Sina_ROR.doc
# 10763
# [{'title': '05-09-23_Johnson_Sina_ROR.docx', 'email': None, 'name': 'JOHNSON, SINA', 'firstnamepatient': 'SINA', 'lastnamepatient': 'JOHNSON', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '05.07.1990', 'dol': '09.17.2022', 'dos': '05.09.23', 'claimno': '202218566', 'gender': None, 'bodyparts': ['left knee', 'left tibia', 'lateral portion of left tibial plateau']}]
# doc no33
# 05-02-23_Jolley_Steve_ROR.doc
# 878
# [{'title': '05-02-23_Jolley_Steve_ROR.docx', 'email': None, 'name': 'JOLLEY, STEVE', 'firstnamepatient': 'STEVE', 'lastnamepatient': 'JOLLEY', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '11/03/1967', 'dol': '12.03.2016', 'dos': '05.01.23', 'claimno': '3008170142-1-10', 'gender': 'M', 'bodyparts': ['MISCELLANEOUS']}]
# doc no34
# 05-06-23_Suazo_Abel_ROR.doc
# 6513
# [{'title': '05-06-23_Suazo_Abel_ROR.docx', 'email': None, 'name': 'SUAZO, ABEL', 'firstnamepatient': 'ABEL', 'lastnamepatient': 'SUAZO', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA, DR. BERNHARD, DR. HUISH, DR. WALKER', 'dob': '01.28.1976', 'dol': '06.23.2022', 'dos': '05.09.23, 06.23.2022, July 6, 2022, July 19, 2022, August 30, 2022, September 8, 2022, September 13, 2022, November 22, 2022, January 9, 2023', 'claimno': None, 'gender': 'M', 'bodyparts': ['Upper extremity – lower arm', 'Right distal biceps', 'Right forearm/bicep', 'Right arm', 'Right antebrachial cutaneous nerve']}]
# doc no35
# 05-05-23_Summers_Daniele_ROR.doc
# 36742
# [{'title': '05-05-23_Summers_Daniele_ROR.docx', 'email': None, 'name': 'SUMMERS, DANIELE SHANON', 'firstnamepatient': 'Daniele', 'lastnamepatient': 'Summers', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '12.03.1985', 'dol': '11.07.2022', 'dos': '05.05.23', 'claimno': '202222349; 001627-154283-WC-01', 'gender': None, 'bodyparts': ['Right ankle', 'Right knee', 'Low back']}]
# doc no36
# 05-10-23_Briggs_Deborah_ROR.doc
# 3385
# [{'title': '05-10-23_Briggs_Deborah_ROR.docx', 'email': None, 'name': 'Briggs, Deborah', 'firstnamepatient': 'Deborah', 'lastnamepatient': 'Briggs', 'middlename': None, 'ssn': None, 'doctor': 'DR. NEWTON', 'dob': '04.02.1962', 'dol': None, 'dos': '05/09/23', 'claimno': '15-00028-B; 19-00389-B', 'gender': None, 'bodyparts': ['head', 'eyes', 'face', 'nose', 'shoulders', 'back', 'neck', 'L ear', 'L ankle']}]
# doc no37
# 05-06-23_Hinojosa Solis_Maria_ROR.doc
# 9362
# [{'title': '05-06-23_Hinojosa Solis_Maria_ROR.docx', 'email': None, 'name': 'HINOJOSA SOLIS, MARIA ISABEL', 'firstnamepatient': 'MARIA ISABEL', 'lastnamepatient': 'HINOJOSA SOLIS', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '01.28.1980', 'dol': '06.08.2016', 'dos': '05.05.23', 'claimno': None, 'gender': 'F', 'bodyparts': ['lumbar spine', 'low back', 'right L4-5', 'right L5', 'right posterior thigh', 'right chest', 'abdominal area']}]
# doc no38
# 05-04-23_Thompson_Lisa_ROR.doc
# 25768
# [{'title': '05-04-23_Thompson_Lisa_ROR.docx', 'email': None, 'name': 'THOMPSON, LISA LYNN', 'firstnamepatient': 'LISA', 'lastnamepatient': 'THOMPSON', 'middlename': 'LYNN', 'ssn': 'XXX-XX-8577', 'doctor': 'DR. FELLARS', 'dob': '01.17.1970', 'dol': None, 'dos': None, 'claimno': None, 'gender': 'F', 'bodyparts': ['head', 'neck', 'upper/middle back', 'lower back', 'right shoulder', 'right foot', 'right leg']}]
# doc no39
# 05-01-23_Medrano_Victor_ROR.doc
# 663
# [{'title': '05-01-23_Medrano_Victor_ROR.doc', 'email': None, 'name': 'MEDRANO, VICTOR', 'firstnamepatient': 'VICTOR', 'lastnamepatient': 'MEDRANO', 'middlename': None, 'ssn': None, 'doctor': 'DR. NEWTON', 'dob': '07/05/1980', 'dol': None, 'dos': '05/02/23', 'claimno': '163023', 'gender': None, 'bodyparts': []}]
# doc no40
# 05-04-23_Hughes_Sharyn_ROR.doc
# 7954
# [{'title': '05-04-23_Hughes_Sharyn_ROR.docx', 'email': None, 'name': 'HUGHES, SHARYN', 'firstnamepatient': 'SHARYN', 'lastnamepatient': 'HUGHES', 'middlename': None, 'ssn': None, 'doctor': 'Peter G. Larcom, M.D.( Utah Orthopaedic Specialists LLC)', 'dob': '07.16.1969', 'dol': '10.28.2022', 'dos': '05.04.23', 'claimno': None, 'gender': None, 'bodyparts': ['right upper extremity', 'right upper arm', 'right elbow', 'right shoulder', 'right hand', 'left upper extremity', 'right humerus', 'right forearm']}]
# doc no41
# 05-02-23_Andrascik_Cody_ROR.doc
# 22117
# [{'title': '05-02-23_Andrascik_Cody_ROR.docx', 'email': None, 'name': 'ANDRASCIK, CODY', 'firstnamepatient': 'CODY', 'lastnamepatient': 'ANDRASCIK', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '06.15.1996', 'dol': '06.02.2020', 'dos': '05.02.23', 'claimno': '7003714907-1-1', 'gender': None, 'bodyparts': ['abdomen', 'knee', 'right lower quadrant', 'head', 'neck', 'shoulder', 'low back', 'lumbar spine', 'pelvis', 'humerus', 'chest', 'thoracic spine', 'left ankle']}]
# doc no42
# 05-02-23_Jolley_Danette_ROR.doc
# 1753
# [{'title': '05-02-23_Jolley_Danette_ROR.docx', 'email': None, 'name': 'Danette Jolley', 'firstnamepatient': 'Danette', 'lastnamepatient': 'Jolley', 'middlename': None, 'ssn': '123-45-6789', 'doctor': 'Dr. Ensalada', 'dob': '03/08/1963', 'dol': '12/03/2016', 'dos': '05/01/2023', 'claimno': '3008170142-1-10', 'gender': 'F', 'bodyparts': ['cervical spine']}]
# doc no43
# 05-05-23_Daniel_Leonard_ROR.doc
# 12312
# [{'title': '05-05-23_Daniel_Leonard_ROR.docx', 'email': None, 'name': 'DANIEL, LEONARD', 'firstnamepatient': 'LEONARD', 'lastnamepatient': 'DANIEL', 'middlename': None, 'ssn': None, 'doctor': 'DR. ENSALADA', 'dob': '09.22.1966', 'dol': '02.23.2022', 'dos': '05.05.23', 'claimno': '202204484', 'gender': 'M', 'bodyparts': ['shoulder']}]
# doc no44
# 05-08-23_Hatfield_Michael_ROR.doc
# 68542
# [{'title': 'Hatfield, Michael Steven', 'email': None, 'name': 'Hatfield, Michael Steven', 'firstnamepatient': 'Michael', 'lastnamepatient': 'Hatfield', 'middlename': None, 'ssn': '555-55-5555', 'doctor': 'Dr. ENSALADA', 'dob': '03/21/1983', 'dol': '11/26/2010', 'dos': '05/08/2023', 'claimno': '201019338', 'gender': 'M', 'bodyparts': ['Back', 'Wrist', 'Ankle']}]
# doc no45
# 05-01-23_Francis_Bryanna_ROR.docx
# 968
# [{'doctor': 'Jordan Daneshzadeh, P.A.-C.', 'date': 'December 6, 2022', 'diagnosis': 'Contusion knee and strain on right knee', 'treatmentplan': 'Prescribed meds and wear splint/brace on R LE frequently', 'workstatus': 'Return to modified work with restrictions of no squatting/kneeling/climbing ladders; no lifting above 10 lbs; ground level work only; should be sitting 90% of the time', 'rTC': 'December 9, 2022'}, {'doctor': 'Larry Bamhart, M.D.', 'date': 'February 28, 2023', 'diagnosis': 'Knee strain, right', 'treatmentplan': 'Patient was released from care', 'workstatus': 'Return to full duty without limitations or restrictions'}]
# doc no46
# 05-05-23_Shaw_Rachael_ROR.docx
# 2655
# [{'title': '05-05-23_Shaw_Rachael_ROR.docx', 'email': None, 'name': 'SHAW, RACHAEL CHRISTINE', 'firstnamepatient': 'RACHAEL', 'lastnamepatient': 'SHAW', 'middlename': 'CHRISTINE', 'ssn': '528-33-9988', 'doctor': ['ADAM CHRISTOPHER GARDNER, PA-C', 'ADAM C. GARDNER, PA-C', 'Kirk R. Dansie, PsyD', 'Vance K. Gunnell, Au.D'], 'dob': '10.30.1978', 'dol': None, 'dos': ['11.20.2020', '01.21.2021', '02.03.2021', '02.16.2021', '01.10.2022', '10.05.2022'], 'claimno': None, 'gender': 'F', 'bodyparts': ['right facial pain', 'right eye', 'right cheek', 'left ear', 'nose', 'sinusitis']}]

# %%
# !pip freeze |grep langchain
# Out:
# langchain==0.1.4
# langchain-community==0.0.14
# langchain-core==0.1.17
